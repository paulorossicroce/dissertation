# %%
#===================================================================IMPORTS
import numpy as np, scipy.stats as st
import scipy.stats
import random
import numpy as np
from datetime import datetime
#===================================================================PARAMETERS
warmup = 30
runs = int(525)  # Number of Replications 69
percentage_traditional = float(0.5)
percentage_crowdshipping = float(0)
percentage_parcel_locker = float(0)
percentage_drone = float(0.5)
debug = "off"
results = "on"
mean_results = "on"
RANDOM_STATE = 31415
now = datetime.now()




#===================================================================FUNCTIONS
def input_csv():
    import csv
    f = open('2021-02-20-frequencias sem outlines-Copy1.csv')
    # f = open('prazos de entrega - expressa e normal.csv')
    texpr = []
    tnorm = []
    csv_f = csv.reader(f, delimiter=';')
    i = 0
    for row in csv_f:
        if i > 0:
            texpr.append(int(row[0]))
            tnorm.append(int(row[1]))
        i = i + 1

    return texpr, tnorm


def input_csv_mix():
    import csv
    f = open('2021-02-20-frequencias sem outlines-Copy1.csv')
    # f = open('prazos de entrega - expressa e normal.csv')
    t = []
    csv_f = csv.reader(f, delimiter=';')
    i = 0
    for row in csv_f:
        if i > 0:
            t.append(int(row[0]))
            t.append(int(row[1]))
        i = i + 1

    return t


def monte_carlo(data):
    results, edges = np.histogram(data, density=True)
    p = []
    sum = 0
    i = 0
    for i in range(len(results)):
        sum = sum + results[i]
        if sum >= 1:
            sum = 1
        p.append(sum)
    x = random.random()
    i = 0
    for i in range(len(p)):
        if x <= p[i]:
            return int(edges[i])
    return int(edges[i])

def mean_confidence_interval_and_h(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n - 1)
    return m, m - h, m + h, h

# Mean Test
replication_km = []
rep_km = []
    
# Timestamp
current_time = now.strftime("%H.%M.%S")
print("Simulation started at: ", current_time)

#===================================================================REPLICATION BEGINS
for l in range(runs):
    
    #Replication Parameters
    day_counter = int(1)
    max_vehicles = int(0)
    min_vehicles = int(100000)
    overall_mileage = int(0)
    overall_packages = int(0)
    cl = 9
    total_days = warmup + 90  # Number of days
    days = total_days
    


    # Crowdshipping
        
    km_crowdshipping_total = float(0)
    crowdshipping_deliveries_total = int(0) 
    total_crowdshipping_vehicles = int(0)
    
    # parcel locker
    km_parcelocker_total = float(0)
    parcelocker_deliveries_total = int(0)
    
    # drone
    km_drone_total = float(0)
    drone_deliveries_total = int(0)

    tw = []

    for t in range(25):
        tw.append(0)

#===================================================================DAILY LOOP
        
    while days > 0:

        resp1 = int(np.random.normal(loc=98, scale=4, size=None))  # Normal Distribuition
        orders_crowdshipping = int(0)
        orders_parcelocker = int(0)
        orders_drone = int(0)

        

                                    # crowdshipping
        km_crowdshipping = []
        crowdshipping_deliveries = []
        crowdshipping_cd = (23 + 2.21)
        crowdshipping_vehicles = int(0)
        km_crowdshipping_daily_total = float(0)
        crowdshipping_deliveries_daily_total = int(0)
        

                                    # parcel locker
        km_parcelocker = float(0)
        parcelocker_deliveries = int(0)
        parcelocker_cd = float(0)

        vehicles_deliveries = int(0)
        vehicles = int(0)

                                    # drone
        km_drone = float(0)
        drone_deliveries = int(0)
        
        
        packages = []
        km = []
        cd = []
        dist_clients = []
        dist_dc = []
        orders = []
        deliveries = int(0)
        total_packages = int(0)
        total_mileage = int(0)
        tw_count = []

        for i in range(len(tw)):
            orders.append(int(0))

                                # Create Orders

        for i in range(resp1):  # Parcel distribuition

            ed = monte_carlo(input_csv_mix())  # gen_delivery
            tw[ed] = tw[ed] + 1
            orders[ed] = orders[ed] + 1

        for i in range(len(tw)):
            tw_count.append(tw[i])
            
                                # Modality Distribuition by percentage
                
        vehicle_deliveries = np.floor((tw[0] * percentage_traditional))
        orders_crowdshipping = np.ceil((tw[0] * (percentage_crowdshipping)))
        orders_parcelocker = np.ceil((tw[0] * (percentage_parcel_locker)))
        orders_drone = np.ceil((tw[0] * (percentage_drone)))
        
        
        
                                
                                # If there is one parcel remaining 
                
        if tw[0] - (vehicle_deliveries + orders_crowdshipping + orders_parcelocker) > 0:
            orders_parcelocker = orders_parcelocker + (
                        tw[0] != (vehicle_deliveries + orders_crowdshipping + orders_parcelocker))

        if vehicle_deliveries > 0:

            if (vehicle_deliveries) % cl > 0:
                vehicles = int(abs(((vehicle_deliveries) // cl) + 1))
            else:
                vehicles = int(abs((vehicle_deliveries) / cl))

        if vehicles > max_vehicles and day_counter > warmup:
            max_vehicles = vehicles

        if vehicles < min_vehicles and vehicles != 0 and day_counter > warmup:
            min_vehicles = vehicles

                                # Append the lists

        for i in range((vehicles)):  # defines the array of packages of a car

            km.append(int(0))
            cd.append(int(0))
            dist_clients.append(int(0))
            dist_dc.append(int(0))

                                # Manage the packages

        if vehicles > 0:
            for i in range(vehicles):
                packages.append(int(0))

                while (vehicle_deliveries) > 0 and packages[i] < int(cl):
                    vehicle_deliveries -= 1
                    tw[0] -= 1
                    packages[i] += 1
                    total_packages += 1
                    if day_counter > (warmup):  # Saves delivery only after warmup days
                        overall_packages += 1

                    deliveries += 1

                            # Calculate the Mileage

            for b in range(int(vehicles)):
                dist_clients[b] = 2.21 * ((packages[b]) - 1)  # Defines the distance between clients
                dist_dc[b] = 23 * 2  # Defines the distance between Distribuition Center and residential area

                km[b] = dist_clients[b] + dist_dc[b]  # Defines the mileage

                total_mileage = total_mileage + km[b]

            if day_counter > (warmup):  # Saves mileage only after 13 days
                overall_mileage = overall_mileage + total_mileage  # Defines the overall km
                rep_km.append(overall_mileage)

                            # Crowdshipping

        if (int(orders_crowdshipping)) % 2 > 0:
            crowdshipping_vehicles = int(abs(((orders_crowdshipping) // 2) + 1))
        else:
            crowdshipping_vehicles = int(abs((orders_crowdshipping) / 2))

        if day_counter > warmup:
            total_crowdshipping_vehicles += crowdshipping_vehicles

        for f in range(crowdshipping_vehicles):  # Defines how many crowdshipping vehicles
            crowdshipping_deliveries.append(0)
            km_crowdshipping.append(0)

        for f in range(crowdshipping_vehicles):

            while (orders_crowdshipping > 0) and (crowdshipping_deliveries[f] < 2):  # crowdshipping parcels
                crowdshipping_deliveries[f] = crowdshipping_deliveries[f] + 1
                orders_crowdshipping -= 1

                if day_counter > warmup:
                    crowdshipping_deliveries_total += 1

                tw[0] = tw[0] - 1

            if (crowdshipping_deliveries[f]) == 2:
                km_crowdshipping[f] = km_crowdshipping[f] + crowdshipping_cd
                if day_counter > warmup:
                    km_crowdshipping_total = km_crowdshipping_total + km_crowdshipping[f]

            if (crowdshipping_deliveries[f]) == 1:
                km_crowdshipping[f] = km_crowdshipping[f] + (crowdshipping_cd - 2.21)
                if day_counter > warmup:
                    km_crowdshipping_total = km_crowdshipping_total + km_crowdshipping[f]
            
            
        for crowd in range (crowdshipping_vehicles):
            km_crowdshipping_daily_total += km_crowdshipping[crowd]
            crowdshipping_deliveries_daily_total += crowdshipping_deliveries[crowd]
            
                

                            # Parcelocker

        parcelocker_cd = 0#(23 + 23 + (1.5 * 12))

        if day_counter > warmup:
            km_parcelocker += parcelocker_cd
            km_parcelocker_total += parcelocker_cd
            parcelocker_deliveries += 0#orders_parcelocker
            parcelocker_deliveries_total += 0#orders_parcelocker

        #tw[0] = tw[0] - orders_parcelocker


                            # Drones

        drone_cd = float(0)
        drone_cd = 5 * orders_drone
        
        if day_counter > warmup:
            km_drone += drone_cd
            km_drone_total += drone_cd
            drone_deliveries += orders_drone
            drone_deliveries_total += orders_drone
        
        tw[0] = tw[0] - orders_drone

                            # Adjust the Time Window

        tw[0] = tw[0] + tw[1]

        for i in range((len(tw) - 2)):
            tw[i + 1] = tw[i + 2]

        tw[24] = 0

        if mean_results == "on":
            mean_km = float(0)
            mean_km = overall_mileage + km_crowdshipping_total + km_parcelocker_total + km_drone_total
            replication_km.append(mean_km)
            del mean_km

#=================================================================== DEBUG            

        if debug == "on":
            print('█████████████████████████dia {}█████████████████████████'.format(day_counter))
            print('\nEstoque inicio do dia: {}'.format(tw_count))
            print('estoque fim do dia: {}'.format(tw))

            print('\n=============================== PEDIDOS TRADICIONAIS ===============================')

            print('\nentregas: {}'.format(deliveries))

            print('veiculos: {}'.format(vehicles))

            print('km: {}'.format(km))
            print('quilometragem: {:.2f}'.format(overall_mileage))
            print('entregas totais: {}'.format(overall_packages))

            print('\n=============================== PEDIDOS CROWDSHIPPING ===============================')
            print('kilometragem: {}'.format(km_crowdshipping))
            print('kilometragem total: {}'.format(km_crowdshipping_daily_total))
            print('entregas: {}'.format(crowdshipping_deliveries))
            print('entregas totais: {}'.format(crowdshipping_deliveries_daily_total))
            print('\n')

            print('\n=============================== PEDIDOS PARCEL LOCKER ===============================')
            print('kilometragem: {}'.format(km_parcelocker))
            print('entregas: {}'.format(parcelocker_deliveries))
            print('\n')
            print('\n=============================== PEDIDOS DRONE ===============================')
            print('kilometragem: {}'.format(km_drone))
            print('entregas: {}'.format(drone_deliveries))
            print('\n')

#=================================================================== DELETES THE PARAMETERS

        del vehicles
        del packages
        del km
        del cd
        del dist_clients
        del dist_dc
        del deliveries
        del total_packages
        del total_mileage
        del tw_count
        del orders
        del vehicles_deliveries
        

                                # Crowdshipping

        del km_crowdshipping
        del km_crowdshipping_daily_total
        del crowdshipping_deliveries
        del crowdshipping_deliveries_daily_total
        del crowdshipping_cd
        del crowdshipping_vehicles

                                # Parcel Locker
        del km_parcelocker
        del parcelocker_deliveries
        del parcelocker_cd
        del orders_parcelocker
        
                                # Drone
        del km_drone
        del drone_deliveries
       # del drone_cd
        del orders_drone

        days = days - 1
        day_counter += 1

#=================================================================== RESULTS SCREEN

    if results == "on":
        print('\n===')
        print('\nReplicação {}'.format(l + 1))
        print('Simulação com {} dias, consolidação de {} '.format(total_days, cl))
        print('===')
        print('\n=============================== PEDIDOS TRADICIONAIS ===============================')
        print('max veiculos tradicional: {}'.format(max_vehicles))
        print('min veiculos tradicional: {}'.format(min_vehicles))
        print('quilometragem tradicional: {:.2f}'.format(overall_mileage))
        print('entregas totais tradicional: {}\n'.format(overall_packages))
        print('\n=============================== PEDIDOS CROWDSHIPPING ===============================')
        print('quilometragem total crowdshipping: {:.2f}\n'.format(km_crowdshipping_total))
        print('entregas totais crowdshipping: {}'.format(crowdshipping_deliveries_total))
        print('Veiculos  utilizados crowdshipping: {}'.format(total_crowdshipping_vehicles))
        print('\n=============================== PEDIDOS PARCEL LOCKER ===============================')
        print('entregas totais parcelocker: {}'.format(parcelocker_deliveries_total))
        print('quilometragem total parcelocker:{}\n'.format(km_parcelocker_total))
        print('\n=============================== PEDIDOS DRONE ===============================')
        print('entregas totais drone: {}'.format(drone_deliveries_total))
        print('quilometragem total drone:{}\n'.format(km_drone_total))

    # APPEND THE MEANS LIST
    

    if runs > 0:
        day_counter = int(1)
        days = total_days
        overall_mileage = int(0)
        overall_packages = int(0)

#=================================================================== RESETS THE REPLICATIONS PARAMETERS
    del km_parcelocker_total
    del parcelocker_deliveries_total
    del km_drone_total
    del drone_deliveries_total
    del total_crowdshipping_vehicles
    del km_crowdshipping_total
    del crowdshipping_deliveries_total
    del total_days
    del cl
    del tw
    del max_vehicles
    del min_vehicles
    del day_counter
    del overall_mileage
    del overall_packages

    data = replication_km




i = 0

if mean_results == "on":
    for i in range(runs):
        rep_km.append(np.mean(replication_km[i]))
    print('\n=============================== MEAN TEST ===============================')    
    print("{} replications".format(runs))
    print("km mean:")
    print(np.mean(rep_km))
    print("km standard deviation:")
    print(np.std(rep_km))
    print("km mean and confidence_interval and h")
    print(mean_confidence_interval_and_h(rep_km))
    print("---------------------------------")
    
now = datetime.now()    
current_time = now.strftime("%H.%M.%S")
print("Simulation ended at: ", current_time)
# Out:
# Simulation started at:  21.13.16
#
# ===
#
# Replicação 1
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32237.05
# entregas totais tradicional: 4323
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4368.0
# quilometragem total drone:21840.0
#
#
# ===
#
# Replicação 2
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32612.91
# entregas totais tradicional: 4394
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4442.0
# quilometragem total drone:22210.0
#
#
# ===
#
# Replicação 3
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32689.44
# entregas totais tradicional: 4389
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4430.0
# quilometragem total drone:22150.0
#
#
# ===
#
# Replicação 4
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32789.87
# entregas totais tradicional: 4375
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4423.0
# quilometragem total drone:22115.0
#
#
# ===
#
# Replicação 5
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32337.89
# entregas totais tradicional: 4329
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4379.0
# quilometragem total drone:21895.0
#
#
# ===
#
# Replicação 6
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 8
# min veiculos tradicional: 5
# quilometragem tradicional: 32792.08
# entregas totais tradicional: 4376
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4425.0
# quilometragem total drone:22125.0
#
#
# ===
#
# Replicação 7
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32803.13
# entregas totais tradicional: 4381
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4429.0
# quilometragem total drone:22145.0
#
#
# ===
#
# Replicação 8
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32856.17
# entregas totais tradicional: 4405
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4458.0
# quilometragem total drone:22290.0
#
#
# ===
#
# Replicação 9
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32381.68
# entregas totais tradicional: 4329
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4377.0
# quilometragem total drone:21885.0
#
#
# ===
#
# Replicação 10
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32469.67
# entregas totais tradicional: 4349
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4391.0
# quilometragem total drone:21955.0
#
#
# ===
#
# Replicação 11
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32401.98
# entregas totais tradicional: 4358
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4390.0
# quilometragem total drone:21950.0
# ===
#
# Replicação 12
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32820.40
# entregas totais tradicional: 4369
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4419.0
# quilometragem total drone:22095.0
#
#
# ===
#
# Replicação 13
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32614.71
# entregas totais tradicional: 4375
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4417.0
# quilometragem total drone:22085.0
#
#
# ===
#
# Replicação 14
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32720.38
# entregas totais tradicional: 4403
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4446.0
# quilometragem total drone:22230.0
#
#
# ===
#
# Replicação 15
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32796.91
# entregas totais tradicional: 4398
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4443.0
# quilometragem total drone:22215.0
#
#
# ===
#
# Replicação 16
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32414.83
# entregas totais tradicional: 4344
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4397.0
# quilometragem total drone:21985.0
#
#
# ===
#
# Replicação 17
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32603.66
# entregas totais tradicional: 4370
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4407.0
# quilometragem total drone:22035.0
#
#
# ===
#
# Replicação 18
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32583.36
# entregas totais tradicional: 4341
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4388.0
# quilometragem total drone:21940.0
#
#
# ===
#
# Replicação 19
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32792.90
# entregas totais tradicional: 4416
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4457.0
# quilometragem total drone:22285.0
#
#
# ===
#
# Replicação 20
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32493.98
# entregas totais tradicional: 4360
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4403.0
# quilometragem total drone:22015.0
#
#
# ===
#
# Replicação 21
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32943.75
# entregas totais tradicional: 4405
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4448.0
# quilometragem total drone:22240.0
#
#
# ===
#
# Replicação 22
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32728.40
# entregas totais tradicional: 4367
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4424.0
# quilometragem total drone:22120.0
# ===
#
# Replicação 23
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32396.74
# entregas totais tradicional: 4316
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4361.0
# quilometragem total drone:21805.0
#
#
# ===
#
# Replicação 24
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 8
# min veiculos tradicional: 5
# quilometragem tradicional: 32550.62
# entregas totais tradicional: 4346
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4395.0
# quilometragem total drone:21975.0
#
#
# ===
#
# Replicação 25
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32491.77
# entregas totais tradicional: 4359
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4402.0
# quilometragem total drone:22010.0
#
#
# ===
#
# Replicação 26
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32243.68
# entregas totais tradicional: 4326
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4368.0
# quilometragem total drone:21840.0
#
#
# ===
#
# Replicação 27
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32976.49
# entregas totais tradicional: 4400
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4447.0
# quilometragem total drone:22235.0
#
#
# ===
#
# Replicação 28
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32987.54
# entregas totais tradicional: 4405
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4445.0
# quilometragem total drone:22225.0
#
#
# ===
#
# Replicação 29
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32662.92
# entregas totais tradicional: 4377
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4420.0
# quilometragem total drone:22100.0
#
#
# ===
#
# Replicação 30
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32798.71
# entregas totais tradicional: 4379
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4429.0
# quilometragem total drone:22145.0
#
#
# ===
#
# Replicação 31
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32520.50
# entregas totais tradicional: 4372
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4420.0
# quilometragem total drone:22100.0
#
#
# ===
#
# Replicação 32
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32603.66
# entregas totais tradicional: 4370
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4416.0
# quilometragem total drone:22080.0
#
#
# ===
#
# Replicação 33
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 33057.85
# entregas totais tradicional: 4417
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4468.0
# quilometragem total drone:22340.0
# ===
#
# Replicação 34
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32480.72
# entregas totais tradicional: 4354
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4399.0
# quilometragem total drone:21995.0
#
#
# ===
#
# Replicação 35
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32594.41
# entregas totais tradicional: 4346
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4399.0
# quilometragem total drone:21995.0
#
#
# ===
#
# Replicação 36
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32397.15
# entregas totais tradicional: 4336
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4378.0
# quilometragem total drone:21890.0
#
#
# ===
#
# Replicação 37
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32566.09
# entregas totais tradicional: 4353
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4394.0
# quilometragem total drone:21970.0
#
#
# ===
#
# Replicação 38
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32342.31
# entregas totais tradicional: 4331
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4374.0
# quilometragem total drone:21870.0
#
#
# ===
#
# Replicação 39
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32673.56
# entregas totais tradicional: 4362
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4411.0
# quilometragem total drone:22055.0
#
#
# ===
#
# Replicação 40
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32316.20
# entregas totais tradicional: 4339
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4388.0
# quilometragem total drone:21940.0
#
#
# ===
#
# Replicação 41
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32599.24
# entregas totais tradicional: 4368
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4409.0
# quilometragem total drone:22045.0
#
#
# ===
#
# Replicação 42
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32673.56
# entregas totais tradicional: 4362
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4403.0
# quilometragem total drone:22015.0
#
#
# ===
#
# Replicação 43
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32454.61
# entregas totais tradicional: 4362
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4403.0
# quilometragem total drone:22015.0
#
#
# ===
#
# Replicação 44
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32741.66
# entregas totais tradicional: 4373
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4409.0
# quilometragem total drone:22045.0
# ===
#
# Replicação 45
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32555.45
# entregas totais tradicional: 4368
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4415.0
# quilometragem total drone:22075.0
#
#
# ===
#
# Replicação 46
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32713.34
# entregas totais tradicional: 4380
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4424.0
# quilometragem total drone:22120.0
#
#
# ===
#
# Replicação 47
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32533.35
# entregas totais tradicional: 4358
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4400.0
# quilometragem total drone:22000.0
#
#
# ===
#
# Replicação 48
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32566.09
# entregas totais tradicional: 4353
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4397.0
# quilometragem total drone:21985.0
#
#
# ===
#
# Replicação 49
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32735.03
# entregas totais tradicional: 4370
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4417.0
# quilometragem total drone:22085.0
#
#
# ===
#
# Replicação 50
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32382.09
# entregas totais tradicional: 4349
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4397.0
# quilometragem total drone:21985.0
#
#
# ===
#
# Replicação 51
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32916.82
# entregas totais tradicional: 4373
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4417.0
# quilometragem total drone:22085.0
#
#
# ===
#
# Replicação 52
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32629.77
# entregas totais tradicional: 4362
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4406.0
# quilometragem total drone:22030.0
#
#
# ===
#
# Replicação 53
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32351.15
# entregas totais tradicional: 4335
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4382.0
# quilometragem total drone:21910.0
#
#
# ===
#
# Replicação 54
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 8
# min veiculos tradicional: 5
# quilometragem tradicional: 32851.75
# entregas totais tradicional: 4403
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4459.0
# quilometragem total drone:22295.0
#
#
# ===
#
# Replicação 55
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32932.29
# entregas totais tradicional: 4380
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4424.0
# quilometragem total drone:22120.0
# ===
#
# Replicação 56
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32658.09
# entregas totais tradicional: 4355
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4400.0
# quilometragem total drone:22000.0
#
#
# ===
#
# Replicação 57
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32634.19
# entregas totais tradicional: 4364
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4410.0
# quilometragem total drone:22050.0
#
#
# ===
#
# Replicação 58
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32861.98
# entregas totais tradicional: 4368
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4416.0
# quilometragem total drone:22080.0
#
#
# ===
#
# Replicação 59
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32957.01
# entregas totais tradicional: 4411
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4461.0
# quilometragem total drone:22305.0
#
#
# ===
#
# Replicação 60
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32789.87
# entregas totais tradicional: 4375
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4420.0
# quilometragem total drone:22100.0
#
#
# ===
#
# Replicação 61
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32620.93
# entregas totais tradicional: 4358
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4410.0
# quilometragem total drone:22050.0
#
#
# ===
#
# Replicação 62
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32730.61
# entregas totais tradicional: 4368
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# ...
# entregas totais drone: 4384.0
# quilometragem total drone:21920.0
#
#
# ===
#
# Replicação 506
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32879.66
# entregas totais tradicional: 4376
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4415.0
# quilometragem total drone:22075.0
# ===
#
# Replicação 507
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32819.01
# entregas totais tradicional: 4408
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4455.0
# quilometragem total drone:22275.0
#
#
# ===
#
# Replicação 508
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32456.82
# entregas totais tradicional: 4363
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4413.0
# quilometragem total drone:22065.0
#
#
# ===
#
# Replicação 509
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32788.07
# entregas totais tradicional: 4394
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4431.0
# quilometragem total drone:22155.0
#
#
# ===
#
# Replicação 510
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32899.55
# entregas totais tradicional: 4385
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4432.0
# quilometragem total drone:22160.0
#
#
# ===
#
# Replicação 511
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32410.00
# entregas totais tradicional: 4322
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4360.0
# quilometragem total drone:21800.0
#
#
# ===
#
# Replicação 512
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32381.68
# entregas totais tradicional: 4329
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4370.0
# quilometragem total drone:21850.0
#
#
# ===
#
# Replicação 513
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 8
# min veiculos tradicional: 5
# quilometragem tradicional: 33182.59
# entregas totais tradicional: 4414
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4449.0
# quilometragem total drone:22245.0
#
#
# ===
#
# Replicação 514
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32574.93
# entregas totais tradicional: 4357
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4393.0
# quilometragem total drone:21965.0
#
#
# ===
#
# Replicação 515
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32915.02
# entregas totais tradicional: 4392
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4436.0
# quilometragem total drone:22180.0
#
#
# ===
#
# Replicação 516
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32662.51
# entregas totais tradicional: 4357
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4401.0
# quilometragem total drone:22005.0
#
#
# ===
#
# Replicação 517
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32678.39
# entregas totais tradicional: 4384
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4432.0
# quilometragem total drone:22160.0
# ===
#
# Replicação 518
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32943.34
# entregas totais tradicional: 4385
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4424.0
# quilometragem total drone:22120.0
#
#
# ===
#
# Replicação 519
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 4
# quilometragem tradicional: 32188.84
# entregas totais tradicional: 4321
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4371.0
# quilometragem total drone:21855.0
#
#
# ===
#
# Replicação 520
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32541.78
# entregas totais tradicional: 4342
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4391.0
# quilometragem total drone:21955.0
#
#
# ===
#
# Replicação 521
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32498.40
# entregas totais tradicional: 4362
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4399.0
# quilometragem total drone:21995.0
#
#
# ===
#
# Replicação 522
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32656.70
# entregas totais tradicional: 4394
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4440.0
# quilometragem total drone:22200.0
#
#
# ===
#
# Replicação 523
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32706.71
# entregas totais tradicional: 4377
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4426.0
# quilometragem total drone:22130.0
#
#
# ===
#
# Replicação 524
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 33002.60
# entregas totais tradicional: 4392
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4437.0
# quilometragem total drone:22185.0
#
#
# ===
#
# Replicação 525
# Simulação com 120 dias, consolidação de 9
# ===
#
# =============================== PEDIDOS TRADICIONAIS ===============================
# max veiculos tradicional: 7
# min veiculos tradicional: 5
# quilometragem tradicional: 32493.57
# entregas totais tradicional: 4340
#
#
# =============================== PEDIDOS CROWDSHIPPING ===============================
# quilometragem total crowdshipping: 0.00
#
# entregas totais crowdshipping: 0
# Veiculos  utilizados crowdshipping: 0
#
# =============================== PEDIDOS PARCEL LOCKER ===============================
# entregas totais parcelocker: 0
# quilometragem total parcelocker:0.0
#
#
# =============================== PEDIDOS DRONE ===============================
# entregas totais drone: 4378.0
# quilometragem total drone:21890.0
#
#
# =============================== MEAN TEST ===============================
# 525 replications
# km mean:
# 16529.601685400317
# km standard deviation:
# 9564.527477732545
# km mean and confidence_interval and h
# (16529.601685400317, 16443.833383704914, 16615.36998709572, 85.76830169540263)
# ---------------------------------
# Simulation ended at:  21.34.45
